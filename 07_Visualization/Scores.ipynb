# %% [markdown]
# # Scores
# Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# Step 2. Create the DataFrame that should look like the one below.

# %%
data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
        'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
        'age': [42, 52, 36, 24, 73],
        'female': [0, 1, 1, 0, 1],
        'preTestScore': [4,24,31,2,3],
        'postTestScore': [25,94,57,62,70]}

df = pd.DataFrame(data)

df
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %% [markdown]
# Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age

# %%
plt.scatter(df['preTestScore'], df['postTestScore'], s=df['age'])
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title('Scatterplot of preTestScore and postTestScore')
plt.show()

# %% [markdown]
# Step 4. Create a Scatterplot of preTestScore and postTestScore.
# This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
plt.scatter(df['preTestScore'], df['postTestScore'], s=df['postTestScore']*4.5, c=df['female'], alpha=0.5)

# Set labels and title
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title('Scatterplot of preTestScore vs postTestScore')

# Show plot
plt.show()

# %% [markdown]
# # BONUS: Create your own question and answer it
# Create a Scatterplot of last_name and age, with the size of each point determined by female

# %%
for i in range(5):
  if(df['female'][i]==0):
    df['female'][i]=10
df['female']
plt.scatter(df['last_name'], df['age'], s=df['female']*20,c = df['female'])
plt.xlabel('last_name')
plt.ylabel('age')
plt.title('Scatterplot of last_name and age')
plt.show()
